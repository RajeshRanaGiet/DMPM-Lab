# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshRanaGiet/DMPM-Lab/blob/main/Experiment%208/Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.array([1,2,3,4])
y = np.array([2,3,4,5])
sum_x = sum(x)
sum_y = sum(y)
sum_xy = sum(x * y)
sum_x2 = sum(x**2)
sum_y2 = sum(y**2)
n = len(x)

r = (n * sum_xy - sum_x * sum_y) / (np.sqrt((n * sum_x2 - sum_x**2) * (n * sum_y2 - sum_y**2)))
print("The Correlation Coefficient is:", r)

x_mean = np.mean(x)
y_mean = np.mean(y)
covariance = np.sum((x - x_mean) * (y - y_mean)) / (n - 1)
print("The Covariance is:", covariance)
# Out:
# The Correlation Coefficient is :  1.0
# The Covarience is :  0.25

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/RajeshRanaGiet/DMPM-Lab/main/Experiment%208/Salary_dataset.csv")
x = np.array(data["YearsExperience"])
y = np.array(data["Salary"])

sum_x = sum(x)
sum_y = sum(y)
sum_xy = sum(x * y)
sum_x2 = sum(x**2)
sum_y2 = sum(y**2)
n = len(x)

r = (n * sum_xy - sum_x * sum_y) / (np.sqrt((n * sum_x2 - sum_x**2) * (n * sum_y2 - sum_y**2)))
print("The Correlation Coefficient is:", r)

x_mean = np.mean(x)
y_mean = np.mean(y)
covariance = np.sum((x - x_mean) * (y - y_mean)) / (n - 1)
print("The Covariance is:", covariance)
# Out:
# The Correlation Coefficient is :  0.9782416184887607
# The Covarience is :  73568.42666666667
